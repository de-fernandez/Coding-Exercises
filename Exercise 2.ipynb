# %% [markdown]
# In this simple assignment you are given a number and have to make it negative. But maybe the number is already negative?
#
# Examples<br>
# make_negative(1);  # return -1<br>
# make_negative(-5); # return -5<br>
# make_negative(0);  # return 0<br>
#
# Notes
# The number can be negative already, in which case no change is required.<br>
# Zero (0) is not checked for any specific sign. Negative zeros make no mathematical sense.<br>

# %%
def make_negative(number):
    if number <= 0:
        result = number
    else:
        result = number * -1
        
    return result

# %%
make_negative(2)
# Out:
# -2

# %%
make_negative(-2)
# Out:
# -2
