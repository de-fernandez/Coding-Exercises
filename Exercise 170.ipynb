# %% [markdown]
# Create a function that accepts a sequence and a non-negative integer n, and returns a sequence of the first n elements from it.
#
# If the sequence has fewer than n elements, return all of them.
#
# Examples<br>
# [0, 1, 2, 3, 5, 8, 13], n = 3  =>  [0, 1, 2]<br>
# [0, 1, 2, 3, 5, 8, 13], n = 0  =>  []<br>
#                     [], n = 3  =>  []<br>

# %%
def take(seq, n):
    result = []

    for i in range(n):
        if i < len(seq):
            result.append(seq[i])

    return result

# %%
take([0, 1, 2, 3, 5, 8, 13], 3) # [0, 1, 2]
# Out:
# [0, 1, 2]
